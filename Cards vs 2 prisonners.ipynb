# %%
'''
# ABOUT
'''
# Author: Matthieu DE MARI (matthieu.de.mari@gmail.com)

from PrisonersCardGame import *

# %%
my_game = CardGame(number_of_cards = 8, fixed_seed = 20510, print_val = True)
# Out:
# A new game has started!
# -----
# The initial configuration (before swap, seed = 20510) is given below.
# -----
# Final results.
# The possible swaps here are: ["('Hearts', 'K') <-> ('Hearts', 'Q')", "('Spades', 'Q') <-> ('Spades', 'K')", "('Hearts', 'A') <-> ('Hearts', 'J')", "('Spades', 'A') <-> ('Spades', 'J')"].

# %%
my_game = CardGame(number_of_cards = 32, fixed_seed = None, print_val = True)
# Out:
# A new game has started!
# -----
# The initial configuration (before swap, seed = 263104523850000133612908237750796288) is given below.
# -----
# Final results.
# The possible swaps here are: ['No swap', "('Hearts', 'J') <-> ('Clubs', '8')", "('Hearts', 'J') <-> ('Spades', 'J')", "('Hearts', 'J') <-> ('Diamonds', '7')", "('Hearts', 'J') <-> ('Hearts', '8')", "('Hearts', 'J') <-> ('Clubs', '7')", "('Hearts', 'J') <-> ('Diamonds', 'A')", "('Hearts', 'J') <-> ('Spades', '8')", "('Hearts', 'J') <-> ('Spades', 'A')", "('Hearts', 'J') <-> ('Spades', '10')", "('Hearts', 'J') <-> ('Hearts', '9')", "('Hearts', 'J') <-> ('Diamonds', 'Q')", "('Hearts', 'J') <-> ('Diamonds', 'J')", "('Hearts', 'J') <-> ('Spades', 'K')", "('Hearts', 'J') <-> ('Clubs', 'J')", "('Hearts', 'J') <-> ('Spades', '7')", "('Hearts', 'J') <-> ('Hearts', 'Q')", "('Hearts', 'J') <-> ('Hearts', 'K')", "('Hearts', 'J') <-> ('Hearts', 'A')", "('Clubs', '8') <-> ('Spades', 'J')", "('Clubs', '8') <-> ('Diamonds', '7')", "('Clubs', '8') <-> ('Clubs', 'Q')", "('Clubs', '8') <-> ('Hearts', '8')", "('Clubs', '8') <-> ('Clubs', '7')", "('Clubs', '8') <-> ('Clubs', '10')", "('Clubs', '8') <-> ('Diamonds', 'A')", "('Clubs', '8') <-> ('Spades', '8')", "('Clubs', '8') <-> ('Spades', '9')", "('Clubs', '8') <-> ('Spades', 'A')", "('Clubs', '8') <-> ('Spades', '10')", "('Clubs', '8') <-> ('Diamonds', '10')", "('Clubs', '8') <-> ('Hearts', '9')", "('Clubs', '8') <-> ('Diamonds', 'Q')", "('Clubs', '8') <-> ('Diamonds', 'J')", "('Clubs', '8') <-> ('Hearts', '7')", "('Clubs', '8') <-> ('Spades', 'K')", "('Clubs', '8') <-> ('Clubs', 'J')", "('Clubs', '8') <-> ('Hearts', '10')", "('Clubs', '8') <-> ('Clubs', 'K')", "('Clubs', '8') <-> ('Clubs', 'A')", "('Clubs', '8') <-> ('Spades', '7')", "('Clubs', '8') <-> ('Spades', 'Q')", "('Clubs', '8') <-> ('Clubs', '9')", "('Clubs', '8') <-> ('Diamonds', 'K')", "('Clubs', '8') <-> ('Hearts', 'Q')", "('Clubs', '8') <-> ('Diamonds', '9')", "('Clubs', '8') <-> ('Diamonds', '8')", "('Clubs', '8') <-> ('Hearts', 'K')", "('Clubs', '8') <-> ('Hearts', 'A')", "('Spades', 'J') <-> ('Diamonds', '7')", "('Spades', 'J') <-> ('Hearts', '8')", "('Spades', 'J') <-> ('Clubs', '7')", "('Spades', 'J') <-> ('Diamonds', 'A')", "('Spades', 'J') <-> ('Spades', '8')", "('Spades', 'J') <-> ('Spades', 'A')", "('Spades', 'J') <-> ('Spades', '10')", "('Spades', 'J') <-> ('Hearts', '9')", "('Spades', 'J') <-> ('Diamonds', 'Q')", "('Spades', 'J') <-> ('Diamonds', 'J')", "('Spades', 'J') <-> ('Spades', 'K')", "('Spades', 'J') <-> ('Clubs', 'J')", "('Spades', 'J') <-> ('Spades', '7')", "('Spades', 'J') <-> ('Hearts', 'Q')", "('Spades', 'J') <-> ('Hearts', 'K')", "('Spades', 'J') <-> ('Hearts', 'A')", "('Diamonds', '7') <-> ('Hearts', '8')", "('Diamonds', '7') <-> ('Clubs', '7')", "('Diamonds', '7') <-> ('Diamonds', 'A')", "('Diamonds', '7') <-> ('Spades', '8')", "('Diamonds', '7') <-> ('Spades', 'A')", "('Diamonds', '7') <-> ('Spades', '10')", "('Diamonds', '7') <-> ('Hearts', '9')", "('Diamonds', '7') <-> ('Diamonds', 'Q')", "('Diamonds', '7') <-> ('Diamonds', 'J')", "('Diamonds', '7') <-> ('Spades', 'K')", "('Diamonds', '7') <-> ('Clubs', 'J')", "('Diamonds', '7') <-> ('Spades', '7')", "('Diamonds', '7') <-> ('Hearts', 'Q')", "('Diamonds', '7') <-> ('Hearts', 'K')", "('Diamonds', '7') <-> ('Hearts', 'A')", "('Clubs', 'Q') <-> ('Clubs', '10')", "('Clubs', 'Q') <-> ('Spades', '9')", "('Clubs', 'Q') <-> ('Spades', '10')", "('Clubs', 'Q') <-> ('Diamonds', '10')", "('Clubs', 'Q') <-> ('Hearts', '7')", "('Clubs', 'Q') <-> ('Hearts', '10')", "('Clubs', 'Q') <-> ('Clubs', 'K')", "('Clubs', 'Q') <-> ('Clubs', 'A')", "('Clubs', 'Q') <-> ('Spades', 'Q')", "('Clubs', 'Q') <-> ('Clubs', '9')", "('Clubs', 'Q') <-> ('Diamonds', 'K')", "('Clubs', 'Q') <-> ('Diamonds', '9')", "('Clubs', 'Q') <-> ('Diamonds', '8')", "('Clubs', 'Q') <-> ('Hearts', 'K')", "('Hearts', '8') <-> ('Clubs', '7')", "('Hearts', '8') <-> ('Diamonds', 'A')", "('Hearts', '8') <-> ('Spades', '8')", "('Hearts', '8') <-> ('Spades', 'A')", "('Hearts', '8') <-> ('Spades', '10')", "('Hearts', '8') <-> ('Hearts', '9')", "('Hearts', '8') <-> ('Diamonds', 'Q')", "('Hearts', '8') <-> ('Diamond ...

# %%
# Do not try for values 16 or 32 (too many combinations to check!)
my_brute_force = BruteForceChecker(number_of_cards = 8, print_val = False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40320/40320 [00:14<00:00, 2692.05it/s]
# All configurations seem to work: our strategy is valid for 8 cards!
