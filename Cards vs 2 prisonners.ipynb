# %%
'''
# ABOUT
'''
# Author: Matthieu DE MARI (matthieu.de.mari@gmail.com)

from PrisonersCardGame import *

# %% [markdown]
# # Checking for 8 cards (no swap configuration)

# %%
my_game = CardGame(number_of_cards = 8, \
                   fixed_seed = 1, \
                   try_brute_force = True, \
                   investigate_orbits = True, \
                   print_val = True)
# Out:
# A new game has started!
# -----
# The initial configuration (before swap, seed = 1) is given below.
# The sorted configuration (for reference) is given below.
# -----
# Looking for list of possible swaps via brute force.
# Done.
# -----
# Investigating orbits and proposing swaps.
# Done.
# -----
# Final results.
# -
# The possible swaps (obtained via brute force) are:
# ...

# %% [markdown]
# # Checking for 8 cards (required swap configuration)

# %%
my_game = CardGame(number_of_cards = 8, \
                   fixed_seed = 20510, \
                   try_brute_force = True, \
                   investigate_orbits = True, \
                   print_val = True)
# Out:
# A new game has started!
# -----
# The initial configuration (before swap, seed = 20510) is given below.
# The sorted configuration (for reference) is given below.
# -----
# Looking for list of possible swaps via brute force.
# Done.
# -----
# Investigating orbits and proposing swaps.
# Done.
# -----
# Final results.
# -
# The possible swaps (obtained via brute force) are:
# ["('Hearts', 'K') <-> ('Hearts', 'Q')", "('Spades', 'Q') <-> ('Spades', 'K')", "('Hearts', 'A') <-> ('Hearts', 'J')", "('Spades', 'A') <-> ('Spades', 'J')"].
# -
# Below are some proposed swaps (obtained via orbit investigation):
# ["('Hearts', 'K') <-> ('Hearts', 'Q')", "('Spades', 'Q') <-> ('Spades', 'K')", "('Spades', 'J') <-> ('Spades', 'A')", "('Hearts', 'J') <-> ('Hearts', 'A')"].
# -
# The configuration admits an orbit whose length is striclty larger than half of the cards: True.
# The proposed swaps are contained in the ones proposed by brute force: True.
# ...

# %% [markdown]
# # Checking for 32 cards (no swap configuration)

# %%
my_game = CardGame(number_of_cards = 32, \
                   fixed_seed = 1, \
                   try_brute_force = True, \
                   investigate_orbits = True, \
                   print_val = True)
# Out:
# A new game has started!
# -----
# The initial configuration (before swap, seed = 1) is given below.
# The sorted configuration (for reference) is given below.
# -----
# Looking for list of possible swaps via brute force.
# Done.
# -----
# Investigating orbits and proposing swaps.
# Done.
# -----
# Final results.
# -
# The possible swaps (obtained via brute force) are:
# ...

# %% [markdown]
# # Checking for 32 cards (required swap configuration)

# %%
my_game = CardGame(number_of_cards = 32, \
                   fixed_seed = 236817753240324158611019456470581248, \
                   try_brute_force = True, \
                   investigate_orbits = True, \
                   print_val = True)
# Out:
# A new game has started!
# -----
# The initial configuration (before swap, seed = 236817753240324158611019456470581248) is given below.
# The sorted configuration (for reference) is given below.
# -----
# Looking for list of possible swaps via brute force.
# Done.
# -----
# Investigating orbits and proposing swaps.
# Done.
# -----
# Final results.
# -
# The possible swaps (obtained via brute force) are:
# ...

# %% [markdown]
# # Checking swaps using bruteforce on all possible cards combinations (8 cards in game)
#
# Run on 16 or 32 at your own risk!

# %%
# Do not try for values 16 or 32 (too many combinations to check!)
my_brute_force = BruteForceChecker(number_of_cards = 8, print_val = False)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40320/40320 [00:19<00:00, 2096.43it/s]
# All configurations seem to work: our strategy is valid for 8 cards!
